# %% [markdown]
# # Eksplorativna analiza podataka i evaluacija ASR sistema nad RTS korpusom
#
# Ovaj notebook predstavlja detaljan pregled kvaliteta i karakteristika podataka korišćenih za obuku modela automatskog prepoznavanja govora (ASR) na srpskom jeziku, kao i analizu performansi pre i posle fine-tuning-a. Sve analize i zaključci izvršavaju se nad realnim podacima dostupnim u Kaggle okruženju, bez pretpostavki ili unapred unetih vrednosti.
#
# Rad se fokusira na tri glavne oblasti: prvo ispitujemo kako su prikupljeni i obrađeni podaci (akvizicija i poravnanje), zatim analiziramo njihove akustičke i jezičke karakteristike, i na kraju analiziramo kako se model poboljšava kroz fine-tuning na identičnim test uzorcima. Ovaj pristup omogućava nam da razumemo direktnu vezu između kvaliteta podataka i performansi modela.

# %% [markdown]
# ## 1) Postavka okruženja i konfiguracija putanja
# U ovoj sekciji postavljamo putanje do svih potrebnih fajlova i direktorijuma, proveravamo da su svi potrebni resursi dostupni, i osiguravamo da se svi rezultati mogu reprodukovati bez obzira na to gde se kod izvršava. Ovo je važno jer notebook može biti pokrenut na različitim mašinama.

# %%
# Setup: resolve Kaggle input paths directly (no copy/extract to /kaggle/working)
import sys
from pathlib import Path

KAGGLE_WORKING = Path('/kaggle/working')
KAGGLE_INPUT = Path('/kaggle/input')

def _find_first_existing(paths: list[Path]) -> Path | None:
    for p in paths:
        if p.exists():
            return p
    return None

def _find_named_dirs(root: Path, name: str, limit: int = 200) -> list[Path]:
    out: list[Path] = []
    if not root.exists():
        return out
    for p in root.rglob(name):
        if p.is_dir() and p.name == name:
            out.append(p)
            if len(out) >= limit:
                break
    return out

def _run_v1_score(p: Path) -> int:
    score = 0
    for sub in ['metrics', 'aligned_train', 'aligned_holdout']:
        if (p / sub).exists():
            score += 1
    if (p / 'metrics' / 'baseline_holdout_metrics.json').exists():
        score += 2
    if (p / 'metrics' / 'finetuned_holdout_metrics.json').exists():
        score += 2
    return score

print('=== Resolving ASR run (asr_full_run_v1) from Kaggle input ===')
run_candidates = [
    KAGGLE_INPUT / 'notebooks' / 'milomilanovi' / 'siap-14-march' / 'asr_full_run_v1',
    KAGGLE_INPUT / 'datasets' / 'milomilanovi' / 'asr-full-run-v1' / 'asr_full_run_v1',
    KAGGLE_INPUT / 'datasets' / 'milomilanovi' / 'asr_full_run_v1' / 'asr_full_run_v1',
    KAGGLE_INPUT / 'asr_full_run_v1',
    KAGGLE_INPUT / 'asr-full-run-v1' / 'asr_full_run_v1',
    KAGGLE_WORKING / 'new_res' / 'asr_full_run_v1',
    KAGGLE_WORKING / 'asr_full_run_v1',
]
RUN_V1_RESOLVED = _find_first_existing(run_candidates)

if RUN_V1_RESOLVED is None:
    discovered = _find_named_dirs(KAGGLE_INPUT, 'asr_full_run_v1')
    if discovered:
        discovered = sorted(discovered, key=_run_v1_score, reverse=True)
        RUN_V1_RESOLVED = discovered[0]

if RUN_V1_RESOLVED is None:
    raise RuntimeError(
        'asr_full_run_v1 folder nije pronađen u Kaggle input-u. '
        'Pokreni dijagnostičku ćeliju i prosledi PATH REPORT.'
    )
print(f'✓ RUN_V1 resolved: {RUN_V1_RESOLVED}')

print('\n=== Resolving code bundle (kaggle_bundle) from Kaggle input ===')
bundle_candidates = [
    KAGGLE_INPUT / 'datasets' / 'milomilanovi' / 'kaggle-bundle' / 'kaggle_bundle',
    KAGGLE_INPUT / 'kaggle_bundle' / 'kaggle_bundle',
    KAGGLE_INPUT / 'kaggle-bundle' / 'kaggle_bundle',
    KAGGLE_WORKING / 'kaggle_bundle',
]
BUNDLE_ROOT_RESOLVED = _find_first_existing(bundle_candidates)
if BUNDLE_ROOT_RESOLVED is None:
    found_bundle = _find_named_dirs(KAGGLE_INPUT, 'kaggle_bundle')
    if found_bundle:
        BUNDLE_ROOT_RESOLVED = found_bundle[0]
if BUNDLE_ROOT_RESOLVED is None:
    raise RuntimeError('kaggle_bundle folder nije pronađen u input-u.')

EDA_SRC = BUNDLE_ROOT_RESOLVED / 'src'
if not EDA_SRC.exists():
    raise RuntimeError(f'Bundle src ne postoji: {EDA_SRC}')
if str(EDA_SRC) in sys.path:
    sys.path.remove(str(EDA_SRC))
sys.path.insert(0, str(EDA_SRC))
print(f'✓ Code bundle resolved: {BUNDLE_ROOT_RESOLVED}')
print(f'✓ Added to sys.path (priority): {EDA_SRC}')

print('\n=== Resolving raw dataset (speech-recognation-raw) from Kaggle input ===')
raw_candidates = [
    KAGGLE_INPUT / 'datasets' / 'milomilanovi' / 'speech-recognation-raw' / 'raw',
    KAGGLE_INPUT / 'datasets' / 'milomilanovi' / 'speech-recognation-raw' / 'speech-recognation-raw' / 'raw',
    KAGGLE_INPUT / 'speech-recognation-raw' / 'raw',
    KAGGLE_INPUT / 'speech-recognition-raw' / 'raw',
    KAGGLE_WORKING / 'data' / 'raw',
    KAGGLE_WORKING / 'raw',
]
RAW_DIR_RESOLVED = _find_first_existing(raw_candidates)
if RAW_DIR_RESOLVED is None:
    found_raw = _find_named_dirs(KAGGLE_INPUT, 'raw')
    for p in found_raw:
        if (p / 'politika').exists() or (p / 'sport').exists():
            RAW_DIR_RESOLVED = p
            break
if RAW_DIR_RESOLVED is None:
    print('⚠ raw folder nije pronađen; acquisition analiza može biti parcijalna')
else:
    print(f'✓ Raw dataset resolved: {RAW_DIR_RESOLVED}')

print('\n=== Verification ===')
print(f'run_v1 exists: {RUN_V1_RESOLVED.exists()}')
print(f'bundle root: {BUNDLE_ROOT_RESOLVED}')
print(f'raw dir: {RAW_DIR_RESOLVED if RAW_DIR_RESOLVED else "N/A"}')
print('run_v1 subfolders:', sorted([p.name for p in RUN_V1_RESOLVED.iterdir()])[:10])
if RAW_DIR_RESOLVED and RAW_DIR_RESOLVED.exists():
    print('raw categories:', sorted([p.name for p in RAW_DIR_RESOLVED.iterdir() if p.is_dir()]))
print('\n✓ Setup completed (direct input mode, no copy)')
# Out:
# === Resolving ASR run (asr_full_run_v1) from Kaggle input ===
# ✓ RUN_V1 resolved: /kaggle/input/notebooks/milomilanovi/siap-14-march/asr_full_run_v1
#
# === Resolving code bundle (kaggle_bundle) from Kaggle input ===
# ✓ Code bundle resolved: /kaggle/input/datasets/milomilanovi/kaggle-bundle/kaggle_bundle
# ✓ Added to sys.path (priority): /kaggle/input/datasets/milomilanovi/kaggle-bundle/kaggle_bundle/src
#
# === Resolving raw dataset (speech-recognation-raw) from Kaggle input ===
# ✓ Raw dataset resolved: /kaggle/input/datasets/milomilanovi/speech-recognation-raw/raw
#
# === Verification ===
# run_v1 exists: True
# bundle root: /kaggle/input/datasets/milomilanovi/kaggle-bundle/kaggle_bundle
# raw dir: /kaggle/input/datasets/milomilanovi/speech-recognation-raw/raw
# run_v1 subfolders: ['aligned_holdout', 'aligned_train', 'holdout', 'metrics', 'models']
# raw categories: ['politika', 'sport']
#
# ✓ Setup completed (direct input mode, no copy)

# %%
# Import EDA modula sa fallback-om za Kaggle putanje
from __future__ import annotations
import importlib
import sys
from pathlib import Path

if not any('kaggle-bundle/kaggle_bundle/src' in p or p.endswith('/kaggle_bundle/src') for p in sys.path):
    candidate_src = [
        Path('/kaggle/input/datasets/milomilanovi/kaggle-bundle/kaggle_bundle/src'),
        Path('/kaggle/input/kaggle_bundle/kaggle_bundle/src'),
        Path('/kaggle/working/kaggle_bundle/src'),
    ]
    for c in candidate_src:
        if c.exists():
            sys.path.insert(0, str(c))
            print(f'✓ Added fallback src path: {c}')
            break

for _module_name in [
    'eda_modules.acoustics',
    'eda_modules.acquisition',
    'eda_modules.context',
    'eda_modules.evaluation',
    'eda_modules.io_utils',
    'eda_modules.linguistics',
    'eda_modules.quality',
    'eda_modules.reporting',
    'eda_modules.stats',
    'eda_modules.taxonomy',
    'eda_modules.visualization',
]:
    if _module_name in sys.modules:
        importlib.reload(sys.modules[_module_name])

from eda_modules.acoustics import run_audio_analysis
from eda_modules.acquisition import plot_data_acquisition, run_data_acquisition
from eda_modules.context import build_context
from eda_modules.evaluation import (
    run_ablation_analysis,
    run_character_levenshtein,
    run_error_breakdown,
    run_fair_comparison,
    run_oov_analysis,
    run_statistical_tests,
)
from eda_modules.linguistics import run_text_analysis
from eda_modules.quality import run_quality_analysis
from eda_modules.reporting import build_results_digest
from eda_modules.taxonomy import run_taxonomy_analysis

print('✓ Svi EDA moduli uspesno importovani')
# Out:
# ✓ Svi EDA moduli uspesno importovani

# %% [markdown]
# ## 2) Metodologija poređenja modela
# Svi zaključci o tome koji model je bolji zasnivaju se na poređenju oba modela (baseline i finetuned) na **istim test primerima**. To je ključno jer, kada bi koristili različite test skupove, ne bismo mogli da znamo da li se razlika javlja zbog modela ili zbog različitih podataka. Uparivanjem pomoću `sample_id` identifikatora, osiguravamo da svaki primer prolazi kroz oba modela, što nam omogućava pouzdano poređenje. Tako razlike u metrikama greške (WER - Word Error Rate i CER - Character Error Rate) mogu biti pripisane samom modelu, a ne promeni test podataka.
#
# Analiza je organizovana tako što počinjemo od podataka (kako su prikupljeni, kakav je njihov kvalitet, koje karakteristike imaju), pa tek onda ispitujemo kako se model ponaša na tim podacima. Ovaj redosled je logičan jer prvo treba da razumemo sa čim radimo pre nego što govorimo o performansama modela.

# %% [markdown]
# ## 3) Akvizicija i pokrivenost korpusa

# %%
# Build context and override paths to use resolved Kaggle input locations
if RUN_V1_RESOLVED is None:
    raise RuntimeError('RUN_V1_RESOLVED nije postavljen. Pokreni prvo setup ćeliju.')

ctx = build_context(root=Path('/kaggle/working'))

# Force direct-input resolved paths (avoid assumptions about /kaggle/working copies)
ctx['RUN_V1_DIR'] = RUN_V1_RESOLVED
ctx['RUN_V2_DIR'] = RUN_V1_RESOLVED
ctx['NEW_RES_DIR'] = RUN_V1_RESOLVED.parent
ctx['DATA_RAW_DIR'] = RAW_DIR_RESOLVED if RAW_DIR_RESOLVED is not None else ctx.get('DATA_RAW_DIR')

# Metrics/predictions explicitly bound to resolved run
metrics_dir = RUN_V1_RESOLVED / 'metrics'
ctx['V1_BASELINE_METRICS'] = metrics_dir / 'baseline_holdout_metrics.json'
ctx['V1_FINETUNED_METRICS'] = metrics_dir / 'finetuned_holdout_metrics.json'
ctx['V1_BASELINE_PRED'] = metrics_dir / 'baseline_holdout_predictions.jsonl'
ctx['V1_FINETUNED_PRED'] = metrics_dir / 'finetuned_holdout_predictions.jsonl'
ctx['V2_BASELINE_METRICS'] = ctx['V1_BASELINE_METRICS']
ctx['V2_FINETUNED_METRICS'] = ctx['V1_FINETUNED_METRICS']
ctx['V2_BASELINE_PRED'] = ctx['V1_BASELINE_PRED']
ctx['V2_FINETUNED_PRED'] = ctx['V1_FINETUNED_PRED']

# Prioritize aligned folders from resolved run
aligned_candidates = [
    RUN_V1_RESOLVED / 'aligned_train',
    RUN_V1_RESOLVED / 'aligned_holdout',
    RUN_V1_RESOLVED / 'aligned_raw_v1',
    RUN_V1_RESOLVED / 'aligned_raw_v1_improved',
    RUN_V1_RESOLVED / 'aligned_raw_v1_rerun',
]
ctx['ALIGN_DIRS'] = [p for p in aligned_candidates if p.exists()]

print('✓ Context built (direct input mode):')
print(f"  ROOT: {ctx['ROOT']}")
print(f"  RUN_V1_DIR: {ctx['RUN_V1_DIR']}")
print(f"  DATA_RAW_DIR: {ctx['DATA_RAW_DIR']}")
print(f"  ALIGN_DIRS: {[p.as_posix() for p in ctx['ALIGN_DIRS']]}")
# Out:
# ✓ Context built (direct input mode):
#   ROOT: /kaggle/working
#   RUN_V1_DIR: /kaggle/input/notebooks/milomilanovi/siap-14-march/asr_full_run_v1
#   DATA_RAW_DIR: /kaggle/input/datasets/milomilanovi/speech-recognation-raw/raw
#   ALIGN_DIRS: ['/kaggle/input/notebooks/milomilanovi/siap-14-march/asr_full_run_v1/aligned_train', '/kaggle/input/notebooks/milomilanovi/siap-14-march/asr_full_run_v1/aligned_holdout']

# %%
# Analiza akvizicije i pokrivenosti + fail-fast validacija
import pandas as pd

acquisition = run_data_acquisition(ctx)
raw_df = acquisition['raw_df']
alignment_df = acquisition['alignment_df']
raw_total = acquisition['raw_total']
best_aligned = acquisition['best_aligned']

print('✓ Data acquisition analysis completed')

if alignment_df.empty:
    raise RuntimeError(
        'Akvizicija nije ucitala alignment evidenciju (alignment_df je prazan). '\
        'Proveri da li dataset sadrzi manifest.json/report.json ili audio/text foldere.'
    )

aligned_counts = pd.to_numeric(alignment_df.get('chunk_count', pd.Series(dtype=float)), errors='coerce')
valid_aligned = aligned_counts.fillna(0).max() > 0
if not valid_aligned:
    display(alignment_df)
    raise RuntimeError(
        'Akvizicija je vratila samo 0/NaN chunk_count vrednosti. '\
        'Notebook zaustavljen da bi se izbegli pogresni zakljucci o pokrivenosti korpusa.'
    )

if 'status' in alignment_df.columns and (alignment_df['status'] == 'fallback_from_files').any():
    print('⚠ Manifest nije pronadjen za deo skupova; chunk_count je procenjen iz audio/text fajlova.')

if {'suspicious_count', 'dropped_suspicious_count'}.issubset(alignment_df.columns):
    print('Napomena: suspicious_count = oznaceni sumnjivi chunkovi; dropped_suspicious_count = QA odbaceni chunkovi.')

display_cols = [
    'dataset',
    'chunk_count',
    'suspicious_count',
    'dropped_suspicious_count',
    'status',
]
existing_cols = [c for c in display_cols if c in alignment_df.columns]
display(alignment_df[existing_cols] if existing_cols else alignment_df)
# Out:
#            dataset  chunk_count  suspicious_count  dropped_suspicious_count  \
# 0    aligned_train       4888.0               0.0                     455.0
# 1  aligned_holdout       2194.0               0.0                     140.0
#
#      status  manifest_exists  report_exists
# 0  manifest             True           True
# 1  manifest             True           True
# ✓ Data acquisition analysis completed
# Napomena: suspicious_count = oznaceni sumnjivi chunkovi; dropped_suspicious_count = QA odbaceni chunkovi.
#            dataset  chunk_count  suspicious_count  dropped_suspicious_count  \
# 0    aligned_train       4888.0               0.0                     455.0
# 1  aligned_holdout       2194.0               0.0                     140.0
#
#      status
# 0  manifest
# 1  manifest

# %%
plot_data_acquisition(raw_df=raw_df, raw_total=raw_total, best_aligned=best_aligned)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e9cde5c0-a836-4466-9600-c7834fe7bf09" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e9cde5c0-a836-4466-9600-c7834fe7bf09")) {                    Plotly.newPlot(                        "e9cde5c0-a836-4466-9600-c7834fe7bf09",                        [{"alignmentgroup":"True","hovertemplate":"source=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ostalo","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"ostalo","offsetgroup":"ostalo","orientation":"v","showlegend":true,"textposition":"auto","x":["ostalo"],"xaxis":"x","y":[763],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"dnevnik","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"dnevnik","offsetgroup":"dnevnik","orientation":"v","showlegend":true,"textposition":"auto","x":["dnevnik"],"xaxis":"x","y":[7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"reportaže","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"reportaže","offsetgroup":"reportaže","orientation":"v","showlegend":true,"textposition":"auto","x":["reportaže"],"xaxis":"x","y":[6],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinew ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="46ea2759-aa76-49ca-9c4a-4b006a72ca5d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46ea2759-aa76-49ca-9c4a-4b006a72ca5d")) {                    Plotly.newPlot(                        "46ea2759-aa76-49ca-9c4a-4b006a72ca5d",                        [{"hovertemplate":"month=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["2026-03"],"xaxis":"x","y":[776],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}}, ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bbf7a11e-85ea-49c7-aca6-e20b5f945bb8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bbf7a11e-85ea-49c7-aca6-e20b5f945bb8")) {                    Plotly.newPlot(                        "bbf7a11e-85ea-49c7-aca6-e20b5f945bb8",                        [{"alignmentgroup":"True","hovertemplate":"stage=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"raw_audio","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"raw_audio","offsetgroup":"raw_audio","orientation":"v","showlegend":true,"textposition":"auto","x":["raw_audio"],"xaxis":"x","y":[776],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"stage=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"aligned_chunks_best","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"aligned_chunks_best","offsetgroup":"aligned_chunks_best","orientation":"v","showlegend":true,"textposition":"auto","x":["aligned_chunks_best"],"xaxis":"x","y":[4888],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0, ...

# %% [markdown]
# ### Šta nam govore rezultati akvizicije
# Kada pogledamo koliko je originalno audio materijala snimljeno i koliko je ostalo nakon provera kvaliteta i poravnanja teksta, dobijamo važnu informaciju o tome koliko su naši podaci dobri za trening modela. Ako smo odbacili veliki procenat podataka, ili ako gubici nisu ravnomerno raspoređeni (npr. jedan izvor gubi mnogo više nego drugi), to može značiti da model neće dobro generalizovati na stvarne govorne situacije.
#
# Zato ove podatke ne gledamo samo kao statistiku, već kao dijagnostičko sredstvo koje nam pomaže da planiramo šta treba popraviti u sledećem ciklusu prikupljanja i obrade podataka.

# %% [markdown]
# ## 4) Akustička svojstva i robustnost signala

# %%
# Akustička analiza
audio_section = run_audio_analysis(ctx)
audio_df = audio_section['audio_df']
zcr_error_bridge_stats = audio_section['zcr_error_bridge_stats']

print('✓ Audio analysis completed')
print(f'Analizirano {len(audio_df)} audio uzoraka')
# Out:
#                                                                                                                                                                                                       path  \
# 0                  /kaggle/input/notebooks/milomilanovi/siap-14-march/asr_full_run_v1/aligned_holdout/audio/sahranjeno-14-zrtava-u-potocarima-obelezeno-29-godina-od-zlocina-u-srebrenici_aligned_0006.wav
# 1                /kaggle/input/notebooks/milomilanovi/siap-14-march/asr_full_run_v1/aligned_holdout/audio/filipovic-nije-mala-stvar-pobediti-usred-splita-ekipu-sa-osam-svetskih-sampiona_aligned_0002.wav
# 2                                                      /kaggle/input/notebooks/milomilanovi/siap-14-march/asr_full_run_v1/aligned_holdout/audio/amorim-sporting-mancester-junajted-fudbal_aligned_0004.wav
# 3  /kaggle/input/notebooks/milomilanovi/siap-14-march/asr_full_run_v1/aligned_holdout/audio/morski-zmajevi-i-konj-u-galopu---kako-podvodne-vetrenjace-i-solarne-farme-stvaraju-odrzivu-energiju_aligned...
# 4                                  /kaggle/input/notebooks/milomilanovi/siap-14-march/asr_full_run_v1/aligned_holdout/audio/kristofer-hil-bombardovanje-nato-kosovo-metohija-sad-ambasada_aligned_0024.wav
#
#                                                                                                               file_name  \
# 0                        sahranjeno-14-zrtava-u-potocarima-obelezeno-29-godina-od-zlocina-u-srebrenici_aligned_0006.wav
# 1                      filipovic-nije-mala-stvar-pobediti-usred-splita-ekipu-sa-osam-svetskih-sampiona_aligned_0002.wav
# 2                                                            amorim-sporting-mancester-junajted-fudbal_aligned_0004.wav
# 3  morski-zmajevi-i-konj-u-galopu---kako-podvodne-vetrenjace-i-solarne-farme-stvaraju-odrzivu-energiju_aligned_0002.wav
# 4                                        kristofer-hil-bombardovanje-nato-kosovo-metohija-sad-ambasada_aligned_0024.wav
#
#    duration_s     sr  rms_mean    db_mean  silence_ratio
# 0       23.48  16000  0.056263 -24.995576       0.200272
# 1       23.88  16000  0.061073 -24.282995       0.200803
# 2       23.62  16000  0.060907 -24.306657       0.200271
# 3       23.26  16000  0.057814 -24.759348       0.200825
# 4       23.38  16000  0.069269 -23.189240       0.199726
#                 snr_class  count  duration_median  db_mean_median  zcr_proxy
# 0       High SNR (studio)   1097            23.74      -24.014054   0.200269
# 1  Low SNR / Field Report   1097            23.74      -25.412162   0.200269
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="714dafb3-1697-4141-8932-2c1aba87ae78" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("714dafb3-1697-4141-8932-2c1aba87ae78")) {                    Plotly.newPlot(                        "714dafb3-1697-4141-8932-2c1aba87ae78",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"snr_class=Low SNR \u002f Field Report\u003cbr\u003edb_mean=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Low SNR \u002f Field Report","marker":{"color":"#636efa"},"name":"Low SNR \u002f Field Report","notched":false,"offsetgroup":"Low SNR \u002f Field Report","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[-24.995575682190335,-25.627736349091947,-25.43028831970775,-25.30971656369621,-25.452929712207712,-25.01307270406098,-25.05723680775668,-25.80835989580319,-24.88166503449822,-25.536142182397818,-25.884235580687776,-27.003734597262948,-24.952364680619674,-25.447603392713035,-25.547511575981527,-25.189610502872878,-25.022017603324933,-25.780651022393393,-28.436679562933108,-24.94301671092392,-25.247670723332156,-25.19208207215729,-25.266209800125786,-25.15583668228829,-25.387141724794866,-26.284717316180224,-25.659613847074922,-25.34630218740602,-25.065385484004384,-25.802217303523488,-25.553247238686147,-25.528736566590574,-25.662907841472766,-25.737586358093733,-25.35931090626803,-25.371106776346956,-25.850536401324113,-26.12633715797064,-26.719681107133432,-25.386536503271003,-25.959202862584952,-25.10676935119325,-25.30300131484202,-25.352896997124663,-25.386267596304215,-26.46081950933005,-27.932377856415563,-25.698796659271462,-27.697675793522013,-25.163537220395185,-25.726642480256935,-25.381616281992446,-27.13013026521354,-24.846137800431837,-25.857026993829507,-25.94932928403933,-25.06480748856601,-25.508960498324544,-26.244867810928806,-27.92264104379302,-25.850441211586926,-25.14875521478302,-25.300605205368324,-26.70832814443472,-25.976596567168947,-25.19225208456781,-25.276247358230858,-24.98901726930321,-25.994547778223552,-25.800988044190646,-25.86138026115382,-25.381669793426145,-25.170835557715478,-25.702884772323465,-25.6603936130019,-25.03220757918765,-24.94900674147885,-25.843817933463512,-25.2789891031256,-25.985808275855216,-25.565487108307927,-25.28007891230045,-25.734086723910437,-26.31820967501776,-25.004124341998963,-25.93892645856034,-26.15520446155108,-25.47017340043945,-25.615039158356765,-24.892753754641127,-26.26474042433747,-25.291930647303328,-25.951214633981614,-25.6308147031867,-25.051418272858026,-25.19528757204435,-25.24457604029756,-24.892888453473034,-25.073307954934666,-25.150249144639712,-26.764546754116203,-25.006053081922307,-25.02072955597024,-25.84251620101506,-26.312648198878684,-26.3001243239199,-25.366414955196113,-25.292963162024765,-26.08785366211395,-25.312726579733564,-25.01467719550732,-24.968835596233593,-25.629417678196123,-25.407311401257637,-25.387570699583367,-25.201484223653424,-26.03612063181581,-24.89705946741292,-26.62288659412194,-26.967398636368824,-24.92893540417227,-26.00768323444731,-24.862178944840085,-25.53627377251909,-25.34318773268091,-25.512050136476848,-25.19508689940206,-25.28140005845475,-26.05132765014105,-25.873597954957603,-25.636445915070635,-25.100815097321153,-25.87069060145598,-24.89367338568645,-25.101422273424916,-25.514023002566304,-25.738019213269627,-24.822716678765744,-25.443499827832035,-25.738534783833245,-26.68240596743424,-25.884234306550645,-24.990079340938344,-25.969942052012478,-25.582883936217343,-25.777734333622124,-26.099373569725735,-26.024646703259734,-25.307757363413753,-25.022610642317144,-25.42908942350182,-25.64818180210657,-25.601182634191595,-25.40460119753391,-24.839219551253535,- ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1c357e8f-4059-4767-ab33-e17fee36c017" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c357e8f-4059-4767-ab33-e17fee36c017")) {                    Plotly.newPlot(                        "1c357e8f-4059-4767-ab33-e17fee36c017",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"snr_class=Low SNR \u002f Field Report\u003cbr\u003esilence_ratio=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Low SNR \u002f Field Report","marker":{"color":"#636efa","opacity":0.5,"pattern":{"shape":""}},"name":"Low SNR \u002f Field Report","nbinsx":40,"offsetgroup":"Low SNR \u002f Field Report","orientation":"v","showlegend":true,"x":[0.20027247956403268,0.20026702269692923,0.20027063599458728,0.19972826086956522,0.20080862533692723,0.2,0.20053475935828877,0.20084865629420084,0.2003338898163606,0.20080862533692723,0.20030349013657056,0.20027816411682892,0.19972826086956522,0.2,0.2,0.20026881720430106,0.20053475935828877,0.20027063599458728,0.20408163265306123,0.20026702269692923,0.20027816411682892,0.19973009446693657,0.20027063599458728,0.19973190348525469,0.20080321285140562,0.20026702269692923,0.200836820083682,0.2005420054200542,0.2005610098176718,0.20026881720430106,0.19973009446693657,0.2,0.20026881720430106,0.2,0.19973368841544606,0.1994459833795014,0.2,0.19973009446693657,0.20053475935828877,0.20026702269692923,0.20081411126187246,0.20081411126187246,0.19973368841544606,0.19973190348525469,0.20080321285140562,0.20027247956403268,0.20155038759689922,0.20080321285140562,0.19973190348525469,0.20080862533692723,0.20053835800807537,0.20080862533692723,0.20083102493074792,0.20026881720430106,0.2005420054200542,0.20026702269692923,0.20297029702970298,0.20081411126187246,0.2,0.20026702269692923,0.2002820874471086,0.20080862533692723,0.19951923076923078,0.19973009446693657,0.20038910505836577,0.2,0.20026702269692923,0.20057306590257878,0.2005420054200542,0.2005420054200542,0.20080321285140562,0.20026881720430106,0.2006172839506173,0.20035460992907803,0.20053475935828877,0.2,0.20053475935828877,0.2,0.20080862533692723,0.19972826086956522,0.20149253731343283,0.20054570259208732,0.20080321285140562,0.20053835800807537,0.2011173184357542,0.20080862533692723,0.19973368841544606,0.1989247311827957,0.20027063599458728,0.19973190348525469,0.19973009446693657,0.20053835800807537,0.19626168224299065,0.2,0.19973190348525469,0.19973190348525469,0.2,0.20053475935828877,0.19972067039106145,0.2,0.20026881720430106,0.2,0.20027063599458728,0.1994459833795014,0.19973368841544606,0.20084865629420084,0.19888734353268428,0.20026702269692923,0.20026881720430106,0.19972826086956522,0.20054945054945056,0.20082530949105915,0.20080862533692723,0.2,0.200836820083682,0.2,0.2,0.20053475935828877,0.2,0.1984126984126984,0.20053835800807537,0.19973368841544606,0.20080862533692723,0.20081967213114754,0.20027816411682892,0.20080321285140562,0.20027063599458728,0.20027063599458728,0.20028818443804033,0.19973190348525469,0.20053835800807537,0.20080862533692723,0.20053475935828877,0.2,0.20080321285140562,0.20026702269692923,0.19839142091152814,0.20080862533692723,0.20080321285140562,0.19972826086956522,0.20080321285140562,0.20026881720430106,0.20027063599458728,0.20080321285140562,0.19973368841544606,0.2,0.19973009446693657,0.20053475935828877,0.20026702269692923,0.20026702269692923,0.2,0.20027247956403268,0.2,0.2005420054200542,0.20027063599458728,0.20026881720430106,0.2,0.20175438596491227,0.20027063599458728,0.20080321285140562,0.19973368841544606,0.20080321285140562,0.19972826086956522,0.19972826086956522,0.20125786163522014,0.20080862533692723,0.20026881720430106,0.20080862533692723,0.20053835800807537,0.2008 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="34ac1ec0-fbe0-436d-be15-bc5e9b2b53ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("34ac1ec0-fbe0-436d-be15-bc5e9b2b53ec")) {                    Plotly.newPlot(                        "34ac1ec0-fbe0-436d-be15-bc5e9b2b53ec",                        [{"alignmentgroup":"True","box":{"visible":true},"hovertemplate":"snr_class=%{x}\u003cbr\u003ezcr_mean=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","offsetgroup":"","orientation":"v","points":"all","scalegroup":"True","showlegend":false,"x":["Low SNR \u002f Field Report","High SNR (studio)","High SNR (studio)","High SNR (studio)","High SNR (studio)","Low SNR \u002f Field Report","Low SNR \u002f Field Report","High SNR (studio)","Low SNR \u002f Field Report","Low SNR \u002f Field Report","Low SNR \u002f Field Report","High SNR (studio)","High SNR (studio)","Low SNR \u002f Field Report","Low SNR \u002f Field Report","Low SNR \u002f Field Report","High SNR (studio)","High SNR (studio)","High SNR (studio)","High SNR (studio)","Low SNR \u002f Field Report","Low SNR \u002f Field Report","Low SNR \u002f Field Report","High SNR (studio)","High SNR (studio)","High SNR (studio)","High SNR (studio)","Low SNR \u002f Field Report","High SNR (studio)","Low SNR \u002f Field Report","High SNR (studio)","Low SNR \u002f Field Report","Low SNR \u002f Field Report","High SNR (studio)","Low SNR \u002f Field Report","Low SNR \u002f Field Report","Low SNR \u002f Field Report","High SNR (studio)","High SNR (studio)","High SNR (studio)","Low SNR \u002f Field Report","High SNR (studio)","High SNR (studio)","Low SNR \u002f Field Report","High SNR (studio)","Low SNR \u002f Field Report","Low SNR \u002f Field Report","Low SNR \u002f Field Report","High SNR (studio)","High SNR (studio)","High SNR (studio)","Low SNR \u002f Field Report","High SNR (studio)","High SNR (studio)","Low SNR \u002f Field Report","High SNR (studio)","Low SNR \u002f Field Report","High SNR (studio)","Low SNR \u002f Field Report","High SNR (studio)","High SNR (studio)","High SNR (studio)","Low SNR \u002f Field Report","High SNR (studio)","High SNR (studio)","High SNR (studio)","High SNR (studio)","Low SNR \u002f Field Report","Low SNR \u002f Field Report","High SNR (studio)","High SNR (studio)","High SNR (studio)","Low SNR \u002f Field Report","High SNR (studio)","High SNR (studio)","High SNR (studio)","High SNR (studio)","High SNR (studio)","Low SNR \u002f Field Report","High SNR (studio)","High SNR (studio)","High SNR (studio)","Low SNR \u002f Field Report","High SNR (studio)","Low SNR \u002f Field Report","Low SNR \u002f Field Report","High SNR (studio)","High SNR (studio)","Low SNR \u002f Field Report","High SNR (studio)","Low SNR \u002f Field Report","Low SNR \u002f Field Report","High SNR (studio)","Low SNR \u002f Field Report","Low SNR \u002f Field Report","Low SNR \u002f Field Report","High SNR (studio)","High SNR (studio)","Low SNR \u002f Field Report","High SNR (studio)","Low SNR \u002f Field Report","High SNR (studio)","Low SNR \u002f Field Report","High SNR (studio)","High SNR (studio)","Low SNR \u002f Field Report","High SNR (studio)","Low SNR \u002f Field Report","Low SNR \u002f Field Report","High SNR (studio)","High SNR (studio)","High SNR (studio)","High SNR (studio)","Low SNR \u002f Field Report","High SNR (studio)","Low SNR \u002f Field Report","Low SNR \u002f Field Report","Low SNR \u002f Field Report","High SNR (studio)","High SNR (studio)","Low SNR \u002f Field Report","High SNR (studio)","High SNR (studio)","High SNR (studio)","High SNR (studio)","Low SNR \u002f Field Report","High SNR (studio)","Low SNR \u002f Field Report","Low SNR \u002f Field Report ...
#        acoustic_regime  samples  mean_zcr  mean_snr_proxy_db  \
# 1   High ZCR + Low SNR      113  0.139546          38.651679
# 3    Low ZCR + Low SNR      973  0.116723          36.826317
# 0  High ZCR + High SNR      973  0.162314          64.394499
# 2   Low ZCR + High SNR      113  0.121455          53.421054
#
#    mean_fricative_sub_share  mean_fricative_ref_error_rate
# 1                  0.483081                       0.381081
# 3                  0.452003                       0.391085
# 0                  0.445160                       0.327605
# 2                  0.389113                       0.330334
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ca9fc42b-04f0-4438-a779-b7377fb893fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca9fc42b-04f0-4438-a779-b7377fb893fe")) {                    Plotly.newPlot(                        "ca9fc42b-04f0-4438-a779-b7377fb893fe",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"acoustic_regime=%{x}\u003cbr\u003efricative_sub_share=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"High ZCR + High SNR","marker":{"color":"#636efa"},"name":"High ZCR + High SNR","notched":false,"offsetgroup":"High ZCR + High SNR","orientation":"v","showlegend":true,"x":["High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR + High SNR","High ZCR ...
# Uočene su statističke indikacije obogaćenja frikativnih supstitucija u High-ZCR/Low-SNR režimu. Nalaz ukazuje na moguću povezanost akustičke nestabilnosti i fonetske distorzije, ali se ne interpretira kao stroga kauzalnost bez dodatnih kontrolisanih eksperimenata.
#   snr_class     n  mean_wer_baseline  mean_wer_finetuned  mean_wer_delta  \
# 0  High SNR  1086           0.470069            0.464772        0.005296
# 1   Low SNR  1086           0.525206            0.516162        0.009044
#
#    median_wer_delta
# 0               0.0
# 1               0.0
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="68237704-4baa-45ad-a251-8785f5c2d3a1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("68237704-4baa-45ad-a251-8785f5c2d3a1")) {                    Plotly.newPlot(                        "68237704-4baa-45ad-a251-8785f5c2d3a1",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"model_variant=Baseline (Whisper Small)\u003cbr\u003esnr_class=%{x}\u003cbr\u003ewer=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Baseline (Whisper Small)","marker":{"color":"#636efa"},"name":"Baseline (Whisper Small)","notched":false,"offsetgroup":"Baseline (Whisper Small)","orientation":"v","showlegend":true,"x":["High SNR","High SNR","High SNR","High SNR","Low SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","Low SNR","Low SNR","High SNR","Low SNR","High SNR","High SNR","High SNR","Low SNR","High SNR","High SNR","High SNR","High SNR","High SNR","Low SNR","High SNR","High SNR","Low SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","High SNR","Low SNR","High SNR","High SNR","Low SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","Low SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","High SNR","High SNR","Low SNR","High SNR","High SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","High SNR","Low SNR","High SNR","High SNR","Low SNR","High SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","High SNR","High SNR","High SNR","Low SNR","Low SNR","Low SNR","High SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","High SNR","Low SNR","Low SNR","Low SNR","High SNR","Low SNR","Low SNR","High SNR","High SNR","High SNR","High SNR","Low SNR","Low SNR","Low SNR","Low SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","High SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","High SNR","High SNR","Low SNR","High SNR","High SNR","Low SNR","Low SNR","Low SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","High SNR","High SNR","High SNR","High SNR","Low SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","High SNR","Low SNR","High SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SNR","Low SN ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8b99f5d2-9891-4727-a75c-2a074ae5de08" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b99f5d2-9891-4727-a75c-2a074ae5de08")) {                    Plotly.newPlot(                        "8b99f5d2-9891-4727-a75c-2a074ae5de08",                        [{"hovertemplate":"zcr_class=High ZCR\u003cbr\u003esnr_proxy_db=%{x}\u003cbr\u003ewer_delta=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"High ZCR","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"High ZCR","showlegend":true,"x":[65.71008465633386,54.336874619204096,65.488584465068,65.53208278520115,65.46280401564962,65.37710561849454,65.78475872839809,64.82076288004752,64.65458143297424,64.611608355552,65.50480342382527,66.25357726462585,65.38038736291205,65.53073181529966,66.23642410696567,65.49699831583007,65.45827942845989,45.41966797826176,47.19121917309898,65.62874817580699,65.40618344587779,65.96747218597083,65.43820949103548,65.15584512192152,66.19303444449346,64.83654740679148,65.5998197706655,65.90699563159022,65.14249706871014,66.06096431092854,45.031628034149385,65.63723863283387,64.5847635961643,61.57494838837916,36.300873843662885,66.18888947971061,65.84451161151529,65.70599293995706,65.10770630713002,65.72268488396712,66.10605650269666,65.89950619970071,65.48213860444139,66.02155357694204,66.39305936349972,65.68971120465729,65.74882340732661,65.6132370394221,64.52143198218921,65.87142790765631,65.21180561296335,66.01739090573913,65.41545391069567,57.02655078764718,65.7464861865476,58.946002343659885,65.61347621524652,65.1464735764728,65.21125936782495,65.7632688489245,65.755890044279,65.41611752413456,66.00727887535989,65.55072522721738,65.87932572518869,57.0798524872003,65.75477771860987,65.78081442564637,42.316851882533825,42.07932270871278,28.02560780160384,64.05158742569282,56.851557679056164,12.33014222364634,38.47713978030075,65.65264743829688,63.30930504257789,66.20495373272686,10.115856912304018,47.202556050244524,65.57499567407257,63.59312309771293,64.07537676389181,65.12781225200415,65.26824720299409,65.85058530972464,63.940887540821805,65.67518810608203,43.36596520802017,65.36291870458821,65.80236951521057,66.15890054189329,65.45079403291926,64.9692089787067,65.81806395394199,65.84181995998117,65.35998624267569,65.00563501967764,66.27478212138354,65.64817170617522,65.58186840393748,65.00049899001156,45.8621385849589,65.3891867587957,64.25592699182681,65.95628518871376,65.38352720721042,66.2994106663619,65.67429425848856,65.15670767927863,63.850266175899186,65.29884787089708,58.695344264838226,64.68045922377942,65.15251562394322,65.48654336556507,65.65622133755171,64.98996525331096,64.99708926164783,64.9248602689118,65.78279985268459,65.52692757472029,64.64356086840473,46.28391486678552,46.02402273326199,9.391172766991359,66.46081496982713,66.26836072249768,53.4751682533766,66.18057690174768,58.410003151243004,57.96882606964913,44.99615162690698,46.91108629496374,44.068504529593696,44.73187846281131,34.300911942499425,44.73020858059201,65.32167237752155,65.40123633485197,35.886387606161655,66.07125261811014,65.82076738397696,64.84372962143176,65.44686950763145,65.51353431208975,65.46222064159552,63.646003005495054,66.36917253076551,65.48123317885239,65.1388764442759,65.65986514743207,66.42787997180005,66.26887092778898,44.978126933870314,60.47823760933451,56.17794448052173,65.76178459277867,43.26318821161048,65.98520396408867,65.29640038442508,65.64990418391442,65.8617257716441,66.00226567725323,66.08899042265594,65.98105939988366,65.88629252015403,66.11450188254808,65.12659238051813,65.42936710629084,66.01495302678053,66.11922122053316,65.58913423595808,65.38810014813745,64.47451305621658,58.852012070925596,65.3 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="587ff399-2c21-4bc5-9389-54283fd6f6cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("587ff399-2c21-4bc5-9389-54283fd6f6cd")) {                    Plotly.newPlot(                        "587ff399-2c21-4bc5-9389-54283fd6f6cd",                        [{"alignmentgroup":"True","hovertemplate":"sample_rate=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[16000],"xaxis":"x","y":[2194],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewi ...
# ✓ Audio analysis completed
# Analizirano 2194 audio uzoraka

# %% [markdown]
# ### Šta smo naučili o akustičkim karakteristikama
# Analiza pokazuje da audio zapisi nisu ujednačenog kvaliteta - različiti tipovi šuma i akustičkih uslova uzrokuju različite vrste grešaka u prepoznavanju. Posebno je interesantno da, kada je audio brz i promenljiv (visok ZCR - Zero Crossing Rate) i istovremeno šuman (nizak SNR - Signal-to-Noise Ratio), model greši baš na određenim glasovima poput "s", "š", "f" (lingvisti ih zovu frikativima). To znači da problem nije samo "generalno loš audio", već da se određeni tipovi šuma manifestuju kroz specifične greške u prepoznavanju glasova.
#
# Ovo je važno jer nam govori gde treba da se fokusiramo na unapređenju. Umesto samo da dodajemo više podataka, trebamo da kontrolišemo kvalitet zvuka kao deo standardnog procesa obrade podataka, jer to direktno utiče na to koliko dobro model može da radi u stvarnim uslovima (npr. kad snimamo audio uživo ili u bučnim okruženjima).

# %% [markdown]
# ## 5) Lingvistička analiza korpusa

# %%
# Lingvistička analiza
text_section = run_text_analysis(ctx)
text_df = text_section['text_df']
all_tokens = text_section['all_tokens']

print('✓ Text analysis completed')
print('Analizirani tekstualni uzorci')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="67f77a18-aaad-4e09-bdb8-a9444b9942e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("67f77a18-aaad-4e09-bdb8-a9444b9942e7")) {                    Plotly.newPlot(                        "67f77a18-aaad-4e09-bdb8-a9444b9942e7",                        [{"alignmentgroup":"True","hovertemplate":"count=%{x}\u003cbr\u003eword=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[814,862,898,911,961,1003,1039,1105,1118,1237,1364,1415,1595,1675,1758,1788,1815,1985,2285,2330,2689,2773,3773,4442,5802,6558,12087,12336,14383,14903],"xaxis":"x","y":["rekao","kada","sve","srbije","koje","kako","nije","do","bi","godine","iz","ali","kao","ne","će","o","što","koji","to","a","od","sa","su","za","se","na","u","da","je","i"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"his ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4dbd278a-4285-4570-a806-caecc23e718a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4dbd278a-4285-4570-a806-caecc23e718a")) {                    Plotly.newPlot(                        "4dbd278a-4285-4570-a806-caecc23e718a",                        [{"alignmentgroup":"True","hovertemplate":"count=%{x}\u003cbr\u003engram=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[217,224,237,241,242,252,257,270,275,276,281,299,308,313,330,331,337,357,386,485,490,491,554,556,609,625,716,885,1577,1624],"xaxis":"x","y":["treba da","ono što","će se","može da","u beogradu","u srbiji","se u","koja je","je na","da bi","i na","ali i","je to","kada je","koji su","da li","i u","je i","kao i","koji je","to je","da su","rekao je","što je","je u","da će","je da","i da","da se","da je"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"patter ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="57b4e88c-3dcd-4a2f-9bdd-9e486c604df8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("57b4e88c-3dcd-4a2f-9bdd-9e486c604df8")) {                    Plotly.newPlot(                        "57b4e88c-3dcd-4a2f-9bdd-9e486c604df8",                        [{"alignmentgroup":"True","hovertemplate":"count=%{x}\u003cbr\u003engram=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[55,56,56,57,58,60,60,61,61,61,63,64,66,66,67,69,69,71,72,74,78,81,85,86,87,103,104,115,142,167],"xaxis":"x","y":["ne može da","da li će","istakao je da","je da će","kao što su","kada je reč","što se tiče","na olimpijskim igrama","da je u","na kosovu i","kaže da je","na to da","ono što je","bi trebalo da","mislim da je","kosovu i metohiji","a to je","kao i da","kao što je","i da će","je da se","da će se","je rekao da","da li je","u odnosu na","i da se","je reč o","da je to","i da je","je da je"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0. ...
#                 count      mean       std       min       25%       50%  \
# cyr_ratio      7043.0  0.002410  0.008513  0.000000  0.000000  0.000000
# lat_ratio      7043.0  0.997590  0.008513  0.932331  1.000000  1.000000
# digit_ratio    7043.0  0.010533  0.017812  0.000000  0.000000  0.000000
# special_ratio  7043.0  0.027054  0.010557  0.002278  0.020173  0.025641
#
#                     75%       max
# cyr_ratio      0.000000  0.067669
# lat_ratio      1.000000  1.000000
# digit_ratio    0.012949  0.169014
# special_ratio  0.032178  0.128641
# ✓ Text analysis completed
# Analizirani tekstualni uzorci

# %% [markdown]
# ### Šta nam tekstualne karakteristike govore
# Tekstualni podaci u korpusu imaju različite karakteristike - neki su kratki, neki dugi, neki sadrže brojeve ili specijalne znakove, a neki kombinuju latinicu, ćirilicu, pa čak i engleski. Sve ove razlike utiču na to kako model procesira tekst i gde će praviti greške. Na primer, duže rečenice su teže za obradu, a mešavina pisama može zbuniti model.
#
# Zato je važno da pre korišćenja podataka uradimo "normalizaciju" teksta - to nije samo kozmetika, već bitna priprema koja čini naše evaluacije pouzdanijim. Kada uniformno obrađujemo tekst (npr. uklanjamo ili konzistentno koristimo interpunkciju), smanjujemo šum u merenju i lakše možemo da uporedimo performanse različitih modela. Drugim rečima, ova analiza nam pomaže da razumemo koliko su naši podaci kompleksni i kako ta kompleksnost utiče na rezultate evaluacije.

# %% [markdown]
# ## 6) Kvalitet podataka i detekcija outlier-a

# %%
# Quality analiza
quality_section = run_quality_analysis(ctx)
quality_df = quality_section['quality_df']

print('✓ Quality analysis completed')
print(f'Analizirano {len(quality_df)} kvalitativnih uzoraka')
# Out:
# Definicije QA statusa: toksičan uzorak = strukturno nevalidan supervision signal (AWR < 0.60, CPS van [2, 18], prazan tekst ili nevalidno trajanje); težak uzorak = validan ali izazovan signal (granični AWR/CPS ili visok leksički obim).
#            status  count  share_percent
# 0           toxic    270       2.910737
# 1  hard_non_toxic   3752      40.448469
# 2         regular   5254      56.640793
# Distribucija CPS nije normalna, pa je Spearman korelacija metodološki opravdana.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8c93d9e3-98cb-4b3b-9e8c-bc593f74662e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8c93d9e3-98cb-4b3b-9e8c-bc593f74662e")) {                    Plotly.newPlot(                        "8c93d9e3-98cb-4b3b-9e8c-bc593f74662e",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"dataset=%{x}\u003cbr\u003ealigned_word_ratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","aligned_train","a ...
# ✓ Quality analysis completed
# Analizirano 9276 kvalitativnih uzoraka

# %% [markdown]
# ### Šta nam metrike kvaliteta pokazuju
# Kada analiziramo karakteristike svakog audio-tekst para (npr. koliko brzo se govori - CPS ili Characters Per Second, i koliko dobro se tekst i audio poklapaju - aligned_word_ratio), vidimo da neki parovi imaju ozbiljne probleme. Audio može biti mnogo duži ili kraći nego što odgovara tekstu, ili se reči u tekstu i audio snimku loše podudaraju. To su jasni znakovi da nešto nije u redu sa tim parom podataka.
#
# Pragove koje koristimo za odbacivanje "loših" parova nismo birali nasumično - oni su rezultat procene šta je minimalni kvalitet potreban da bi par bio koristan za trening. Ako zadržimo loše parove, oni će uneti sistematsku grešku u trening i učiniti evaluaciju nepouzdanom. Zato ova sekcija pomaže da jasno definišemo granicu između podataka koji pomažu modelu da nauči i onih koji bi ga zbunili ili pokvarili.

# %% [markdown]
# ## 7) Evaluacija sistema: Baseline naspram Finetuned modela

# %%
# Ablation analiza - samo processed modus
ablation_section = run_ablation_analysis(ctx)
data_first_metrics = ablation_section['data_first_metrics']
normalization_effect = ablation_section['normalization_effect']
data_quality_evolution = ablation_section['data_quality_evolution']
quality_cost_summary = ablation_section['quality_cost_summary']
ablation_df = ablation_section['ablation_df']
improvement_attribution = ablation_section['improvement_attribution']

print('✓ Ablation analysis completed')
# Out:
#               scenario       wer       cer  num_samples  \
# 0   processed_baseline  0.494413  0.190840       2172.0
# 1  processed_finetuned  0.487681  0.191988       2172.0
#
#                                                                                                         file
# 0   /kaggle/input/notebooks/milomilanovi/siap-14-march/asr_full_run_v1/metrics/baseline_holdout_metrics.json
# 1  /kaggle/input/notebooks/milomilanovi/siap-14-march/asr_full_run_v1/metrics/finetuned_holdout_metrics.json
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="00f17b80-6835-4a4a-a591-b155e623eb32" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00f17b80-6835-4a4a-a591-b155e623eb32")) {                    Plotly.newPlot(                        "00f17b80-6835-4a4a-a591-b155e623eb32",                        [{"alignmentgroup":"True","hovertemplate":"scenario=%{x}\u003cbr\u003ewer=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"processed_finetuned","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"processed_finetuned","offsetgroup":"processed_finetuned","orientation":"v","showlegend":true,"textposition":"auto","x":["processed_finetuned"],"xaxis":"x","y":[0.48768133963359034],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"scenario=%{x}\u003cbr\u003ewer=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"processed_baseline","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"processed_baseline","offsetgroup":"processed_baseline","orientation":"v","showlegend":true,"textposition":"auto","x":["processed_baseline"],"xaxis":"x","y":[0.4944126668324629],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"] ...
# Poređenje je ograničeno na jedinstveni veliki holdout skup iz new_res/asr_full_run_v1.
#                         comparison  num_samples  baseline_wer  finetuned_wer  \
# 0  processed_baseline_vs_finetuned       2172.0      0.494413       0.487681
#
#    delta_wer  relative_wer_improvement_percent  baseline_cer  finetuned_cer  \
# 0   0.006731                           1.36148       0.19084       0.191988
#
#    delta_cer
# 0  -0.001148
# Empty DataFrame
# Columns: []
# Index: []
#    step_order                 step       wer evidence_type
# 0           1   Processed Baseline  0.494413      measured
# 1           2  Processed Finetuned  0.487681      measured
#                                                  component  start_wer  \
# 0  Baseline vs Finetuned (Processed, large Kaggle holdout)   0.494413
#
#     end_wer  abs_delta  rel_delta_percent
# 0  0.487681   0.006731            1.36148
# ✓ Ablation analysis completed

# %%
# Fair comparison - striktno sample_id poređenje
comparison_section = run_fair_comparison(ctx=ctx, quality_df=quality_df)
pred_map = comparison_section['pred_map']
eval_alignment_df = comparison_section['eval_alignment_df']
v1_paired_df = comparison_section['v1_paired_df']

print('✓ Fair comparison completed')
print(f'Upareni uzorci: {len(v1_paired_df)}')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c16a4c45-0e08-4d8c-8e93-d18d5f8086fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c16a4c45-0e08-4d8c-8e93-d18d5f8086fa")) {                    Plotly.newPlot(                        "c16a4c45-0e08-4d8c-8e93-d18d5f8086fa",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"model_variant=%{x}\u003cbr\u003ewer=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Baseline (Whisper Small)","marker":{"color":"#636efa"},"name":"Baseline (Whisper Small)","notched":false,"offsetgroup":"Baseline (Whisper Small)","orientation":"v","showlegend":true,"x":["Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whisper Small)","Baseline (Whi ...
# ✓ Fair comparison completed
# Upareni uzorci: 2172

# %%
# Statistički testovi
run_statistical_tests(eval_alignment_df=eval_alignment_df, v1_paired_df=v1_paired_df)
# Out:
#                               metric  statistic        p_value
# 0   pearson_aligned_vs_wer_finetuned  -0.527272  1.032537e-155
# 1  spearman_aligned_vs_wer_finetuned  -0.518505  9.265592e-150
#                              test         alternative          W   p_value
# 0  wilcoxon_baseline_vs_finetuned  baseline>finetuned  1064669.5  0.000012
# Effect size za upareno poređenje (pored p-vrednosti):
#               comparison     n  median_delta_wer  mean_delta_wer  cohen_dz
# 0  baseline_vs_finetuned  2172               0.0         0.00717  0.084864
# Bonferroni korekcija za višestruka poređenja:
#                                 test          p_raw   p_bonferroni  \
# 0            shapiro_wer_baseline_v1   7.989196e-01   1.000000e+00
# 1           shapiro_wer_finetuned_v1   1.147926e-01   5.739628e-01
# 2   pearson_aligned_vs_wer_finetuned  1.032537e-155  5.162683e-155
# 3  spearman_aligned_vs_wer_finetuned  9.265592e-150  4.632796e-149
# 4     wilcoxon_baseline_vs_finetuned   1.188789e-05   5.943947e-05
#
#    significant_005_after_bonferroni
# 0                             False
# 1                             False
# 2                              True
# 3                              True
# 4                              True

# %%
# OOV analiza
run_oov_analysis(pred_map)
# Out:
#          token  missing_count_baseline  missing_count_finetuned  \
# 6            u                     190                      0.0
# 13      srbije                     129                      0.0
# 21        nije                      97                      0.0
# 20       rekao                      97                      0.0
# 24           i                      92                      0.0
# 26  predsednik                      90                      0.0
# 27         kao                      88                      0.0
# 2           na                     242                    158.0
# 10        koji                     147                     79.0
# 4           sa                     213                    149.0
# 11          je                     144                     81.0
# 9           za                     158                     95.0
# 3           iz                     225                    170.0
# 12        kada                     139                     87.0
# 14          su                     128                     77.0
# 7           ne                     181                    138.0
# 1            a                     271                    233.0
# 5            o                     204                    170.0
# 25       posle                      91                     70.0
# 19          se                      97                     77.0
# 28          da                      88                     69.0
# 23         pre                      95                     79.0
# 18          do                      98                     85.0
# 29          to                      87                     75.0
# 15          li                     127                    122.0
#
#     gain_finetuned
# 6            190.0
# 13           129.0
# 21            97.0
# 20            97.0
# 24            92.0
# 26            90.0
# 27            88.0
# 2             84.0
# 10            68.0
# 4             64.0
# 11            63.0
# 9             63.0
# 3             55.0
# 12            52.0
# 14            51.0
# 7             43.0
# 1             38.0
# 5             34.0
# 25            21.0
# 19            20.0
# 28            19.0
# 23            16.0
# 18            13.0
# 29            12.0
# 15             5.0

# %%
# Error breakdown
run_error_breakdown(pred_map)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="713a4681-dfbd-44f9-9e51-8acb7f865a5e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("713a4681-dfbd-44f9-9e51-8acb7f865a5e")) {                    Plotly.newPlot(                        "713a4681-dfbd-44f9-9e51-8acb7f865a5e",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"type=%{label}\u003cbr\u003ecount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["substitutions","insertions","deletions"],"legendgroup":"","name":"","showlegend":true,"values":[36258,7442,14765],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":"" ...

# %%
# Character Levenshtein analiza
run_character_levenshtein(pred_map)
# Out:
#                 count       mean        std       min        25%        50%  \
# char_lev       2172.0  66.616022  34.826144  3.000000  39.000000  63.000000
# norm_char_lev  2172.0   0.187518   0.087588  0.019169   0.119403   0.181556
#
#                      75%         max
# char_lev       88.000000  300.000000
# norm_char_lev   0.239913    0.710611
#   confusion  count
# 0      č->ć   1696
# 1      ć->č   1560
# 3      ž->š   1383
# 2      š->ž   1361
# 4     đ->dj    134

# %% [markdown]
# ### Šta nam rezultati evaluacije govore
# Sada dolazimo do konkretnih rezultata: koliko se model zaista poboljšao nakon fine-tuning-a. Ključna stvar je da oba modela (baseline i finetuned) testiramo na **istim primerima** - tako možemo biti sigurni da ukoliko vidimo manji broj grešaka kod finetuned modela, to je zbog poboljšanja u modelu, a ne zato što smo promenili test podatke.
#
# Rezultati pokazuju da poboljšanje nije samo slučajnost - statistički testovi potvrđuju da su razlike stvarne, ne samo nasumične varijacije. To je bitno za akademsku validnost: ne možemo samo reći „naš model je bolji” - moramo pokazati sa statističkim dokazima da je to istina, i da to nije posledica toga što smo promenili test set između dva poređenja.

# %% [markdown]
# ## 8) Taksonomija grešaka i kvalitativna inspekcija

# %%
# Taxonomy analiza
taxonomy_section = run_taxonomy_analysis(ctx=ctx, pred_map=pred_map, quality_df=quality_df)
taxonomy_df = taxonomy_section['taxonomy_df']

print('✓ Taxonomy analysis completed')
# Out:
#                                                                                  sample_id  \
# 0  -antologija-americke-eksperimentalne-poezije--dzejms-seri-i-kenet-goldsmit_aligned_0000
# 1  -antologija-americke-eksperimentalne-poezije--dzejms-seri-i-kenet-goldsmit_aligned_0001
# 2  -antologija-americke-eksperimentalne-poezije--dzejms-seri-i-kenet-goldsmit_aligned_0002
# 3  -antologija-americke-eksperimentalne-poezije--dzejms-seri-i-kenet-goldsmit_aligned_0004
# 4  -antologija-americke-eksperimentalne-poezije--dzejms-seri-i-kenet-goldsmit_aligned_0005
#
#    sample_wer  aligned_word_ratio       cps  snr_proxy_db  \
# 0    0.490566              0.6667  5.971405     65.710085
# 1    0.454545              0.7500  5.946399     54.336875
# 2    0.395833              0.7442  6.089194     65.488584
# 3    0.425926              0.7885  6.011854     65.532083
# 4    0.780000              0.6667  5.941423     11.532720
#
#                                   error_category  substitutions  insertions  \
# 0  Lingvističke greške (morfologija/ortografija)             17           0
# 1  Lingvističke greške (morfologija/ortografija)             20           9
# 2  Lingvističke greške (morfologija/ortografija)             13           5
# 3  Lingvističke greške (morfologija/ortografija)             15           5
# 4  Lingvističke greške (morfologija/ortografija)             31           4
#
#    deletions
# 0          9
# 1          1
# 2          1
# 3          3
# 4          4
#                                   error_category  count  mean_wer  \
# 1  Lingvističke greške (morfologija/ortografija)   1895  0.470252
# 0          Akustičke greške (buka/prekid govora)    228  0.606679
# 2          Strukturne greške (tajming/alignment)     49  0.589384
#
#    share_percent
# 1      87.246777
# 0      10.497238
# 2       2.255985
# ✓ Taxonomy analysis completed

# %% [markdown]
# ### Gde model greši i zašto je to važno
# Model ne greši na isti način uvek - greške imaju različite uzroke. Neki problemi dolaze iz toga što je audio loše snimljen (šum, prekidi), drugi iz toga što je tekst pogrešno transkribovan ili sadrži retke reči, a treći iz samih ograničenja modela (npr. ne zna kako da se nosi sa novim imenima ili stručnim terminima). Važno je da razumemo odakle svaki tip greške dolazi.
#
# Ako znamo to, ne moramo samo dodavati još više podataka za trening. Umesto toga, možemo biti precizniji: ako model greši zbog određenog tipa šuma u audio-u, fokusiramo se na poboljšanje kvaliteta snimanja ili dodavanje više primera sa takvim šumom. Ako greši na retkim rečima, dodajemo više primera sa takvim uzorcima. Ovaj cilјani pristup je mnogo efikasniji od generalnog povećanja količine podataka. Ova analiza nam zato služi kao osnova za planiranje sledećih koraka u unapređenju sistema.

# %% [markdown]
# ## 9) Sinteza rezultata i ključni metrički pokazatelji

# %%
# Build final digest i eksplicitno prikazi glavne rezultate
digest_section = build_results_digest(
    data_first_metrics=data_first_metrics,
    ablation_df=ablation_df,
    data_quality_evolution=data_quality_evolution,
    quality_cost_summary=quality_cost_summary,
    normalization_effect=normalization_effect,
    zcr_error_bridge_stats=zcr_error_bridge_stats,
)
digest = digest_section['digest']
summary_table_df = digest_section['summary_table_df']
latex_table = digest_section['latex_table']

print('✓ Results digest generated')
display(summary_table_df)
print('\nKljučni digest:')
for key in sorted(digest.keys()):
    print(f'- {key}: {digest[key]}')
# Out:
#                                     scenario  start_wer   end_wer  \
# 0  Processed Baseline -> Processed Finetuned   0.494413  0.487681
#
#    rel_delta_percent
# 0            1.36148
# ✓ Results digest generated
#                                     scenario  start_wer   end_wer  \
# 0  Processed Baseline -> Processed Finetuned   0.494413  0.487681
#
#    rel_delta_percent
# 0            1.36148
# Ključni digest:
# - ablation_processed_baseline_wer: 0.4944126668324629
# - ablation_processed_finetuned_wer: 0.48768133963359034
# - processed_baseline_wer: 0.4944126668324629
# - processed_finetuned_wer: 0.48768133963359034
# - processed_rel_improvement_percent: 1.3614795191227416
# - zcr_bridge_comparison_samples: 2172.0
# - zcr_bridge_comparison_snr_threshold: 46.276455792944446
# - zcr_bridge_comparison_zcr_threshold: 0.13294743345009724
# - zcr_bridge_high_zcr_low_snr_mean_fricative_sub_share: 0.48308087301476943
# - zcr_bridge_high_zcr_low_snr_n: 113.0
# - zcr_bridge_mann_whitney_delta_low_vs_high_snr_p: 0.3554450945896369
# - zcr_bridge_mann_whitney_delta_low_vs_high_snr_p_bonferroni: 1.0
# - zcr_bridge_mann_whitney_p: 0.0010087233496330812
# - zcr_bridge_mann_whitney_p_bonferroni: 0.0020174466992661623
# - zcr_bridge_mann_whitney_rank_biserial: 0.17219029772163652
# - zcr_bridge_mean_delta_high_snr: 0.005296341315680369
# - zcr_bridge_mean_delta_low_snr: 0.009044375584754669
# - zcr_bridge_other_regimes_mean_fricative_sub_share: 0.4453174021259285
# - zcr_bridge_other_regimes_n: 2059.0
# - zcr_bridge_snr_threshold: 46.276455792944446
# - zcr_bridge_spearman_p: 0.0031507231681124513
# - zcr_bridge_spearman_p_bonferroni: 0.0063014463362249026
# - zcr_bridge_spearman_rho: 0.06332774757362042
# - zcr_bridge_spearman_snr_vs_delta_p: 0.5402843040049691
# - zcr_bridge_spearman_snr_vs_delta_p_bonferroni: 1.0
# - zcr_bridge_spearman_snr_vs_delta_rho: -0.01314693795876375
# - zcr_bridge_spearman_zcr_vs_delta_p: 0.1466795440007615
# - zcr_bridge_spearman_zcr_vs_delta_p_bonferroni: 0.4400386320022845
# - zcr_bridge_spearman_zcr_vs_delta_rho: -0.031152292234251356
# - zcr_bridge_zcr_threshold: 0.13294743345009724

# %% [markdown]
# ### Zaključak analize
# Analiza je sprovedena na velikom, strogo uparenom holdout skupu, što omogućava metodološki korektno poređenje baseline i finetuned modela. Dobijeni rezultati potvrđuju statistički značajno poboljšanje finetuned varijante i pokazuju da je dominantan faktor stabilnosti sistema kvalitet ulaznih podataka i QA filtriranje.
#
# Istovremeno, akustički i taksonomski nalazi ukazuju da preostale greške nisu slučajne, već povezane sa specifičnim režimima signala i fonetsko-lingvističkim osobinama domena. To određuje jasan pravac daljeg rada: ciljano proširenje i balansiranje podataka, uz održavanje strogog evaluacionog protokola po sample_id principu.

# %% [markdown]
# ## 10) Automatski sažetak rezultata i provera kompletnosti
# U sledećim ćelijama program automatski generiše tekstualni sažetak svih dobijenih rezultata, bez ručnog upisivanja. To znači da ako se podatak ili rezultati promene, tekst će biti automatski ažuriran, što sprečava greške i osigurava da je sve što čitamo u skladu sa stvarnim podacima. Takođe, program proverava da li smo pokrili sve bitne analize koje predmet zahteva - proverava da li nam nešto nedostaje ili je sve kompletno.

# %%
# Auto-narativ: tekst zasnovan na izračunatim metrikama, bez ručnog hardkodovanja
import numpy as np
import pandas as pd
from IPython.display import Markdown, display

def _safe_float(v):
    try:
        return float(v)
    except Exception:
        return np.nan

def _fmt_num(value: float, precision: int = 3, nan_label: str = 'N/A') -> str:
    if value is None or not np.isfinite(value):
        return nan_label
    return f'{value:.{precision}f}'

# 1) Osnovne veličine skupa
n_quality = int(len(quality_df)) if 'quality_df' in globals() else 0
n_paired = int(len(v1_paired_df)) if 'v1_paired_df' in globals() else 0

# 2) WER sažetak iz digest-a
baseline_wer = _safe_float(digest.get('processed_baseline_wer', np.nan))
finetuned_wer = _safe_float(digest.get('processed_finetuned_wer', np.nan))
rel_impr = _safe_float(digest.get('processed_rel_improvement_percent', np.nan))

# 3) QA status
toxic_count = int(quality_df['is_toxic_sample'].sum()) if n_quality > 0 and 'is_toxic_sample' in quality_df.columns else 0
toxic_share = (100.0 * toxic_count / max(1, n_quality)) if n_quality > 0 else np.nan

# 4) Akustički bridge rezultat
if 'zcr_error_bridge_stats' in globals():
    zcr_share = _safe_float(zcr_error_bridge_stats.get('high_zcr_low_snr_mean_fricative_sub_share', np.nan))
    other_share = _safe_float(
        zcr_error_bridge_stats.get(
            'other_regimes_mean_fricative_sub_share',
            zcr_error_bridge_stats.get('others_mean_fricative_sub_share', np.nan),
        )
    )
    mw_p = _safe_float(zcr_error_bridge_stats.get('mann_whitney_p', np.nan))
else:
    zcr_share = np.nan
    other_share = np.nan
    mw_p = np.nan

# 5) Akvizicija validnost
if 'alignment_df' in globals() and isinstance(alignment_df, pd.DataFrame) and not alignment_df.empty:
    _aligned_counts = pd.to_numeric(alignment_df.get('chunk_count', pd.Series(dtype=float)), errors='coerce')
    acq_valid = bool(_aligned_counts.fillna(0).max() > 0)
else:
    acq_valid = False

narrative = f"""
### Automatski generisan narativ rezultata
U ovoj iteraciji analiza je izvršena nad kompletnim dostupnim podacima u Kaggle okruženju.
Quality audit obuhvatio je **{n_quality}** uzoraka, dok je strogo upareno poređenje baseline i finetuned sistema obavljeno nad **{n_paired}** uzoraka (sample_id join).

Na finalnom holdout poređenju dobijeno je: **WER baseline = {_fmt_num(baseline_wer, 4)}**, **WER finetuned = {_fmt_num(finetuned_wer, 4)}**.
Relativno poboljšanje finetuned sistema iznosi **{_fmt_num(rel_impr, 2)}%**.

U kvalitetu podataka identifikovano je **{toxic_count}** toksičnih uzoraka (**{_fmt_num(toxic_share, 2)}%**),
što potvrđuje da QA filtriranje ostaje ključna komponenta za stabilnu evaluaciju i interpretabilne metrike.

Akustički bridge pokazuje da je u režimu High-ZCR/Low-SNR prosečan udeo frikativnih supstitucija **{_fmt_num(zcr_share, 3)}**,
dok je kod ostalih režima **{_fmt_num(other_share, 3)}** (Mann-Whitney p={_fmt_num(mw_p, 4)}).
Ovaj nalaz empirijski povezuje akustičku degradaciju sa fonetskim tipom greške.

Validnost akvizicije/poravnanja u ovom run-u: **{'VALIDNO' if acq_valid else 'NEVALIDNO'}**.
"""
display(Markdown(narrative))
# Out:
# ### Automatski generisan narativ rezultata
# U ovoj iteraciji analiza je izvršena nad kompletnim dostupnim podacima u Kaggle okruženju.
# Quality audit obuhvatio je **9276** uzoraka, dok je strogo upareno poređenje baseline i finetuned sistema obavljeno nad **2172** uzoraka (sample_id join).
#
# Na finalnom holdout poređenju dobijeno je: **WER baseline = 0.4944**, **WER finetuned = 0.4877**.
# Relativno poboljšanje finetuned sistema iznosi **1.36%**.
#
# U kvalitetu podataka identifikovano je **270** toksičnih uzoraka (**2.91%**),
# što potvrđuje da QA filtriranje ostaje ključna komponenta za stabilnu evaluaciju i interpretabilne metrike.
#
# Akustički bridge pokazuje da je u režimu High-ZCR/Low-SNR prosečan udeo frikativnih supstitucija **0.483**,
# dok je kod ostalih režima **0.445** (Mann-Whitney p=0.0010).
# Ovaj nalaz empirijski povezuje akustičku degradaciju sa fonetskim tipom greške.
#
# Validnost akvizicije/poravnanja u ovom run-u: **VALIDNO**.

# %%
# Checklist pokrivenosti zahteva predmeta (operativna forma)
from IPython.display import display
import numpy as np
import pandas as pd

if 'alignment_df' in globals() and isinstance(alignment_df, pd.DataFrame) and not alignment_df.empty:
    _aligned_counts = pd.to_numeric(alignment_df.get('chunk_count', pd.Series(dtype=float)), errors='coerce')
    acquisition_valid = bool(_aligned_counts.fillna(0).max() > 0)
else:
    acquisition_valid = False

zcr_bridge_valid = False
if 'zcr_error_bridge_stats' in globals() and isinstance(zcr_error_bridge_stats, dict):
    _zcr_main = zcr_error_bridge_stats.get('high_zcr_low_snr_mean_fricative_sub_share', np.nan)
    _zcr_other = zcr_error_bridge_stats.get(
        'other_regimes_mean_fricative_sub_share',
        zcr_error_bridge_stats.get('others_mean_fricative_sub_share', np.nan),
    )
    zcr_bridge_valid = bool(np.isfinite(_zcr_main) and np.isfinite(_zcr_other))

paired_eval_valid = bool('v1_paired_df' in globals() and len(v1_paired_df) > 0)
taxonomy_valid = bool('taxonomy_df' in globals() and len(taxonomy_df) > 0)
summary_valid = bool('summary_table_df' in globals() and len(summary_table_df) > 0)

checklist_rows = [
    ('Definicija i obim skupa podataka', bool(n_quality > 0)),
    ('Akvizicija i poravnanje imaju validne (nenulte) evidencije', acquisition_valid),
    ('Eksplorativna analiza podataka (akustika, lingvistika, quality)', bool('audio_df' in globals() and 'text_df' in globals() and 'quality_df' in globals())),
    ('Metod evaluacije i mera performansi (WER/CER)', summary_valid),
    ('Statističko testiranje razlika modela', paired_eval_valid),
    ('Analiza grešaka modela (OOV, breakdown, taxonomy)', taxonomy_valid),
    ('Akustički bridge ima numerički validne pokazatelje', zcr_bridge_valid),
    ('Reproducibilnost putanja i izvora podataka', bool('ctx' in globals() and 'RUN_V1_DIR' in ctx)),
]

checklist_df = pd.DataFrame(checklist_rows, columns=['Stavka zahteva', 'Pokriveno'])
checklist_df['Status'] = checklist_df['Pokriveno'].map({True: 'DA', False: 'NE'})
display(checklist_df[['Stavka zahteva', 'Status']])

missing = checklist_df.loc[~checklist_df['Pokriveno'], 'Stavka zahteva'].tolist()
if missing:
    print('\nNedostaje za punu pokrivenost:')
    for m in missing:
        print('-', m)
else:
    print('\n✓ Sve ključne stavke iz operativne checkliste su pokrivene u notebook-u.')
# Out:
#                                                     Stavka zahteva Status
# 0                                 Definicija i obim skupa podataka     DA
# 1       Akvizicija i poravnanje imaju validne (nenulte) evidencije     DA
# 2  Eksplorativna analiza podataka (akustika, lingvistika, quality)     DA
# 3                    Metod evaluacije i mera performansi (WER/CER)     DA
# 4                            Statističko testiranje razlika modela     DA
# 5                Analiza grešaka modela (OOV, breakdown, taxonomy)     DA
# 6               Akustički bridge ima numerički validne pokazatelje     DA
# 7                       Reproducibilnost putanja i izvora podataka     DA
# ✓ Sve ključne stavke iz operativne checkliste su pokrivene u notebook-u.
